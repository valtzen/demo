# %% [markdown]
# # ECMWF Open Data Access (Novice Level)
#
# This notebook guides you through accessing and exploring ECMWF Open Data.
#
# We'll use ECMWF-supported tools where possible, and keep the interface beginner-friendly with interactive widgets and clear steps.
#
# Focus: **Open Data from IFS Operational Forecast model**
#
# ---

# %% [markdown]
# ## 1. Setup & Imports
#
# We import essential libraries, prioritizing ECMWF packages (`earthkit`, `eccodes`).

# %%
import os
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup
from IPython.display import display, Markdown
import ipywidgets as widgets

# Optional: ECMWF-supported GRIB reader
from earthkit.data import from_source

# %% [markdown]
# ## 2. Check Earthkit Installation
#
# This cell checks that the `earthkit` package is installed correctly and prints its version.
# Earthkit combines data access (`earthkit.data`) and visualization (`earthkit.plots`) tools developed by ECMWF.
# We check and print the library versions because plotting choices depend on installed versions.
#
# Docs: [Earthkit Overview](https://earthkit.readthedocs.io)

# %%
import earthkit; print(earthkit.__version__)
# Out:
# 0.11.2

# %% [markdown]
# ## 3. Select Forecast to Download
#
# We'll provide dropdowns to select the forecast date, run hour, model, and lead time.
#
# Only `.grib2` forecast files are shown (index files are excluded).

# %%
BASE_URL = "https://data.ecmwf.int/forecasts/"

# --- Step 1: Fetch available forecast dates from ECMWF ---
r = requests.get(BASE_URL)
soup = BeautifulSoup(r.text, "html.parser")

available_dates = sorted([
    a.text.strip("/") for a in soup.find_all("a")
    if a.text.strip("/").isdigit() and len(a.text.strip("/")) == 8
], reverse=True)

model_dropdown = widgets.Dropdown(
    options=["0p25/oper", "0p25/enfo", "0p25/waef", "0p25/wave"],
    value="0p25/oper",
    description="Model:"
)

date_dropdown = widgets.Dropdown(
    options=available_dates,
    value=available_dates[0],
    description="Date:"
)

hour_dropdown = widgets.Dropdown(
    options=["00z", "06z", "12z", "18z"],
    value="00z",
    description="Model Run:"
)

forecast_dropdown = widgets.Dropdown(
    options=[],
    description="Forecast Step:",
)

def update_forecast_options(*_):
    folder_url = f"{BASE_URL}{date_dropdown.value}/{hour_dropdown.value}/ifs/{model_dropdown.value}/"
    try:
        r = requests.get(folder_url)
        soup = BeautifulSoup(r.text, "html.parser")
        grib_files = [a['href'] for a in soup.find_all("a") if a['href'].endswith(".grib2") and "index" not in a['href']]
        short_options = [(f.split("-")[1], os.path.basename(f)) for f in grib_files]  # ("0h", "filename")
        forecast_dropdown.options = short_options
    except Exception as e:
        forecast_dropdown.options = []
        print("Error fetching forecast list:", e)

date_dropdown.observe(update_forecast_options, names='value')
hour_dropdown.observe(update_forecast_options, names='value')
model_dropdown.observe(update_forecast_options, names='value')

update_forecast_options()

display(widgets.VBox([date_dropdown, hour_dropdown, model_dropdown, forecast_dropdown]))
# Out:
# VBox(children=(Dropdown(description='Date:', options=('20250812', '20250811', '20250810', '20250809'), value='…

# %% [markdown]
# ## 4. Download Selected Forecast Data
#
# Once a file is selected, click to download it to the `../data` folder.

# %%
download_button = widgets.Button(description="⬇️ Download GRIB File", button_style="primary")
download_output = widgets.Output()

def handle_download(_):
    download_output.clear_output()
    with download_output:
        date, hour, model, file_name = date_dropdown.value, hour_dropdown.value, model_dropdown.value, forecast_dropdown.value
        folder_url = f"{BASE_URL}{date}/{hour}/ifs/{model}/"
        full_url = urljoin(folder_url, file_name)
        os.makedirs("../data", exist_ok=True)
        local_path = os.path.join("../data", os.path.basename(file_name))
        print(f"📄 Selected: {file_name}")
        print(f"🔗 URL: {full_url}")

        if not os.path.exists(local_path):
            print("⬇️ Downloading...")
            with requests.get(full_url, stream=True) as r:
                r.raise_for_status()
                with open(local_path, "wb") as f:
                    for chunk in r.iter_content(chunk_size=8192):
                        f.write(chunk)
            print(f"✅ File saved to: {local_path}")
        else:
            print(f"✅ File already exists: {local_path}")

        globals()['local_path'] = local_path

download_button.on_click(handle_download)
display(download_button, download_output)
# Out:
# Button(button_style='primary', description='⬇️ Download GRIB File', style=ButtonStyle())
# Output()

# %% [markdown]
# ## 5. Load and Explore Forecast Data
#
# We'll use `earthkit.data` to load the file.

# %%
# Load GRIB using earthkit
ds = from_source("file", local_path)
ds.describe()
# Out:
# <style type="text/css">
# #T_5eb38 th {
#   text-align: left;
# }
# #T_5eb38_row0_col0, #T_5eb38_row0_col1, #T_5eb38_row0_col2, #T_5eb38_row0_col3, #T_5eb38_row0_col4, #T_5eb38_row0_col5, #T_5eb38_row0_col6, #T_5eb38_row0_col7, #T_5eb38_row0_col8, #T_5eb38_row0_col9, #T_5eb38_row1_col0, #T_5eb38_row1_col1, #T_5eb38_row1_col2, #T_5eb38_row1_col3, #T_5eb38_row1_col4, #T_5eb38_row1_col5, #T_5eb38_row1_col6, #T_5eb38_row1_col7, #T_5eb38_row1_col8, #T_5eb38_row1_col9, #T_5eb38_row2_col0, #T_5eb38_row2_col1, #T_5eb38_row2_col2, #T_5eb38_row2_col3, #T_5eb38_row2_col4, #T_5eb38_row2_col5, #T_5eb38_row2_col6, #T_5eb38_row2_col7, #T_5eb38_row2_col8, #T_5eb38_row2_col9, #T_5eb38_row3_col0, #T_5eb38_row3_col1, #T_5eb38_row3_col2, #T_5eb38_row3_col3, #T_5eb38_row3_col4, #T_5eb38_row3_col5, #T_5eb38_row3_col6, #T_5eb38_row3_col7, #T_5eb38_row3_col8, #T_5eb38_row3_col9, #T_5eb38_row4_col0, #T_5eb38_row4_col1, #T_5eb38_row4_col2, #T_5eb38_row4_col3, #T_5eb38_row4_col4, #T_5eb38_row4_col5, #T_5eb38_row4_col6, #T_5eb38_row4_col7, #T_5eb38_row4_col8, #T_5eb38_row4_col9, #T_5eb38_row5_col0, #T_5eb38_row5_col1, #T_5eb38_row5_col2, #T_5eb38_row5_col3, #T_5eb38_row5_col4, #T_5eb38_row5_col5, #T_5eb38_row5_col6, #T_5eb38_row5_col7, #T_5eb38_row5_col8, #T_5eb38_row5_col9, #T_5eb38_row6_col0, #T_5eb38_row6_col1, #T_5eb38_row6_col2, #T_5eb38_row6_col3, #T_5eb38_row6_col4, #T_5eb38_row6_col5, #T_5eb38_row6_col6, #T_5eb38_row6_col7, #T_5eb38_row6_col8, #T_5eb38_row6_col9, #T_5eb38_row7_col0, #T_5eb38_row7_col1, #T_5eb38_row7_col2, #T_5eb38_row7_col3, #T_5eb38_row7_col4, #T_5eb38_row7_col5, #T_5eb38_row7_col6, #T_5eb38_row7_col7, #T_5eb38_row7_col8, #T_5eb38_row7_col9, #T_5eb38_row8_col0, #T_5eb38_row8_col1, #T_5eb38_row8_col2, #T_5eb38_row8_col3, #T_5eb38_row8_col4, #T_5eb38_row8_col5, #T_5eb38_row8_col6, #T_5eb38_row8_col7, #T_5eb38_row8_col8, #T_5eb38_row8_col9, #T_5eb38_row9_col0, #T_5eb38_row9_col1, #T_5eb38_row9_col2, #T_5eb38_row9_col3, #T_5eb38_row9_col4, #T_5eb38_row9_col5, #T_5eb38_row9_col6, #T_5eb38_row9_col7, #T_5eb38_row9_col8, #T_5eb38_row9_col9, #T_5eb38_row10_col0, #T_5eb38_row10_col1, #T_5eb38_row10_col2, #T_5eb38_row10_col3, #T_5eb38_row10_col4, #T_5eb38_row10_col5, #T_5eb38_row10_col6, #T_5eb38_row10_col7, #T_5eb38_row10_col8, #T_5eb38_row10_col9, #T_5eb38_row11_col0, #T_5eb38_row11_col1, #T_5eb38_row11_col2, #T_5eb38_row11_col3, #T_5eb38_row11_col4, #T_5eb38_row11_col5, #T_5eb38_row11_col6, #T_5eb38_row11_col7, #T_5eb38_row11_col8, #T_5eb38_row11_col9, #T_5eb38_row12_col0, #T_5eb38_row12_col1, #T_5eb38_row12_col2, #T_5eb38_row12_col3, #T_5eb38_row12_col4, #T_5eb38_row12_col5, #T_5eb38_row12_col6, #T_5eb38_row12_col7, #T_5eb38_row12_col8, #T_5eb38_row12_col9, #T_5eb38_row13_col0, #T_5eb38_row13_col1, #T_5eb38_row13_col2, #T_5eb38_row13_col3, #T_5eb38_row13_col4, #T_5eb38_row13_col5, #T_5eb38_row13_col6, #T_5eb38_row13_col7, #T_5eb38_row13_col8, #T_5eb38_row13_col9, #T_5eb38_row14_col0, #T_5eb38_row14_col1, #T_5eb38_row14_col2, #T_5eb38_row14_col3, #T_5eb38_row14_col4, #T_5eb38_row14_col5, #T_5eb38_row14_col6, #T_5eb38_row14_col7, #T_5eb38_row14_col8, #T_5eb38_row14_col9, #T_5eb38_row15_col0, #T_5eb38_row15_col1, #T_5eb38_row15_col2, #T_5eb38_row15_col3, #T_5eb38_row15_col4, #T_5eb38_row15_col5, #T_5eb38_row15_col6, #T_5eb38_row15_col7, #T_5eb38_row15_col8, #T_5eb38_row15_col9, #T_5eb38_row16_col0, #T_5eb38_row16_col1, #T_5eb38_row16_col2, #T_5eb38_row16_col3, #T_5eb38_row16_col4, #T_5eb38_row16_col5, #T_5eb38_row16_col6, #T_5eb38_row16_col7, #T_5eb38_row16_col8, #T_5eb38_row16_col9, #T_5eb38_row17_col0, #T_5eb38_row17_col1, #T_5eb38_row17_col2, #T_5eb38_row17_col3, #T_5eb38_row17_col4, #T_5eb38_row17_col5, #T_5eb38_row17_col6, #T_5eb38_row17_col7, #T_5eb38_row17_col8, #T_5eb38_row17_col9, #T_5eb38_row18_col0, #T_5eb38_row18_col1, #T_5eb38_row18_col2, #T_5eb38_row18_col3, #T_5eb38_row18_col4, #T_5eb38_row18_col5, #T_5eb38_row18_col6, #T_5eb38_row18_col7, #T_5eb38_row18_col8, #T_5eb38_row18_col9, #T_5eb38_row19_col0, #T_5eb38_row19_col1, #T_5eb38_row19_col2, #T_5eb38_row19_col3, #T_5eb38_row19_col4, #T_5e ...

# %% [markdown]
# ## 6. Plot Forecast Data with Earthkit
#
# We use `earthkit.data.from_source` to load the downloaded GRIB data.
# This creates a dataset object (`ds`) that holds all forecast fields (variables, levels, and metadata) in memory.
#
# To quickly visualise the contents, we use `earthkit.plots.quickplot`, a convenient one-line function that creates a sensible default map.
#
# ### Available Parameters
#
# In the previous cell we already printed the available parameters from the dataset you have downloaded and the full description of ECMWF Open Data parameters is documented here:
# [https://www.ecmwf.int/en/forecasts/datasets/open-data](https://www.ecmwf.int/en/forecasts/datasets/open-data)
#
# In this section, we’ll select one of these parameters (e.g., `2t` for 2m temperature) and plot it using the built-in quicklplot method.

# %%
# Select the 2m temperature field (shortName = "2t")
t2m = ds.sel(shortName="2t")[0]

earthkit.plots.quickplot(t2m)
# Out:
# ECCODES WARNING :  Key gridSpec is not yet implemented. Work in progress...
